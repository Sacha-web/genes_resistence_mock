# %%
# Análise exploratória de genes de resistência antimicrobiana
# Este notebook realiza uma análise exploratória de genes de resistência antimicrobiana a partir de dados simulados com base no CARD Database. O objetivo é demonstrar um pipeline básico de análise e visualização em Python, aplicável a dados reais de metagenômica ambiental.

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
df = pd.read_csv('/content/drive/MyDrive/Sacha/Projeto Bioinformática/card_genes_resistance_mock.csv')
df.head()
# Out:
#   ARO Accession    ARO Name      Drug Class             Resistance Mechanism  \
# 0   ARO:3000001       TEM-1     beta-lactam          Antibiotic inactivation
# 1   ARO:3000002       NDM-1      carbapenem           Metallo-beta-lactamase
# 2   ARO:3000003  AAC(6')-Ib  aminoglycoside                Acetyltransferase
# 3   ARO:3000004       MCR-1       polymyxin  Phosphoethanolamine transferase
#
#   Protein Accession
# 0    WP_000123456.1
# 1    WP_000654321.1
# 2    WP_000789012.1
# 3    WP_000345678.1

# %%
from collections import Counter
import matplotlib.pyplot as plt

# %%
from collections import Counter

classe_counts = Counter(df['Drug Class'])

# %%
# Plotar gráfico
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="Drug Class", palette="Set2", order=df["Drug Class"].value_counts().index)
plt.title("Distribuição de genes de resistência por classe de antibiótico")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-6-153655378.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="Drug Class", palette="Set2", order=df["Drug Class"].value_counts().index)

# %%
plt.figure(figsize=(7,5))
sns.countplot(data=df, x="Resistance Mechanism", palette="pastel")
plt.title("Distribuição por mecanismo de resistência")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-17-4023571674.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="Resistance Mechanism", palette="pastel")

# %%
classes_interesse = ['beta-lactam']
filtro_multiplos = df[df['Drug Class'].isin(classes_interesse)]

# %%
# Visualizar gráfico só com esse filtro
sns.countplot(data=filtro_beta, x='Resistance Mechanism', palette='Set2')
plt.title("Mecanismos de resistência a beta-lactam")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-19-1150000831.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=filtro_beta, x='Resistance Mechanism', palette='Set2')

# %%
## ✅ Conclusão

#Este projeto demonstrou uma análise básica de dados antimicrobianos com foco em resistência, usando um conjunto de dados simulado.
#Você pode adaptar este modelo para dados reais do CARD ou outras fontes como MG-RAST.

#*Autora: Sacha Gonzaga*
